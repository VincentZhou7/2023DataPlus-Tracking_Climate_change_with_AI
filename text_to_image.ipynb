# %% [markdown]
# # Text-to-Image Search via CLIP
#
# <a href="https://colab.research.google.com/drive/1yKnmy2Qotrh3OhgwWRsMWPFwOSAecBxg?usp=sharing"><img alt="Open In Colab" src="https://colab.research.google.com/assets/colab-badge.svg"></a>
#
# Traditionally, searching images from text (text-image-retrieval) relies heavily on human annotations, this is commonly referred to as *Text/Tag-based Image Retrieval (TBIR)*.
#
# The [OpenAI CLIP](https://github.com/openai/CLIP) model maps the dense vectors extracted from text and image into the same semantic space and produces a strong zero-shot model to measure the similarity between text and images.
#
# This guide will showcase fine-tuning a `CLIP` model for text-to-image retrieval.
#
# *Note, please consider switching to GPU/TPU Runtime for faster inference.*
#
# ## Install

# %%
pip install 'finetuner[full]'
# Out:
# Requirement already satisfied: finetuner[full] in ./.local/lib/python3.8/site-packages (0.7.8)
# Requirement already satisfied: trimesh==3.16.4 in ./.local/lib/python3.8/site-packages (from finetuner[full]) (3.16.4)
# Requirement already satisfied: docarray[common]<0.30.0 in ./.local/lib/python3.8/site-packages (from finetuner[full]) (0.21.1)
# Requirement already satisfied: finetuner-stubs==0.13.7 in ./.local/lib/python3.8/site-packages (from finetuner[full]) (0.13.7)
# Requirement already satisfied: jina-hubble-sdk==0.33.1 in ./.local/lib/python3.8/site-packages (from finetuner[full]) (0.33.1)
# Requirement already satisfied: finetuner-commons==0.13.7; extra == "full" in ./.local/lib/python3.8/site-packages (from finetuner[full]) (0.13.7)
# Requirement already satisfied: numpy in ./.local/lib/python3.8/site-packages (from trimesh==3.16.4->finetuner[full]) (1.23.1)
# Requirement already satisfied: rich>=12.0.0 in ./.local/lib/python3.8/site-packages (from docarray[common]<0.30.0->finetuner[full]) (13.4.2)
# Requirement already satisfied: fastapi; extra == "common" in ./.local/lib/python3.8/site-packages (from docarray[common]<0.30.0->finetuner[full]) (0.98.0)
# Requirement already satisfied: uvicorn; extra == "common" in ./.local/lib/python3.8/site-packages (from docarray[common]<0.30.0->finetuner[full]) (0.22.0)
# Requirement already satisfied: pydantic>=1.9.0; extra == "common" in ./.local/lib/python3.8/site-packages (from docarray[common]<0.30.0->finetuner[full]) (1.10.9)
# Requirement already satisfied: requests; extra == "common" in /usr/lib/python3/dist-packages (from docarray[common]<0.30.0->finetuner[full]) (2.22.0)
# Requirement already satisfied: lz4; extra == "common" in ./.local/lib/python3.8/site-packages (from docarray[common]<0.30.0->finetuner[full]) (4.3.2)
# Requirement already satisfied: matplotlib; extra == "common" in /usr/lib/python3/dist-packages (from docarray[common]<0.30.0->finetuner[full]) (3.1.2)
# Requirement already satisfied: protobuf>=3.13.0; extra == "common" in ./.local/lib/python3.8/site-packages (from docarray[common]<0.30.0->finetuner[full]) (3.20.3)
# Requirement already satisfied: Pillow; extra == "common" in /usr/lib/python3/dist-packages (from docarray[common]<0.30.0->finetuner[full]) (7.0.0)
# Requirement already satisfied: typing-extensions==4.5.0 in ./.local/lib/python3.8/site-packages (from finetuner-stubs==0.13.7->finetuner[full]) (4.5.0)
# Requirement already satisfied: pathspec in ./.local/lib/python3.8/site-packages (from jina-hubble-sdk==0.33.1->finetuner[full]) (0.11.1)
# Requirement already satisfied: importlib-metadata in ./.local/lib/python3.8/site-packages (from jina-hubble-sdk==0.33.1->finetuner[full]) (6.7.0)
# Requirement already satisfied: filelock in /usr/lib/python3/dist-packages (from jina-hubble-sdk==0.33.1->finetuner[full]) (3.0.12)
# Requirement already satisfied: aiohttp in ./.local/lib/python3.8/site-packages (from jina-hubble-sdk==0.33.1->finetuner[full]) (3.8.4)
# Requirement already satisfied: pyyaml in ./.local/lib/python3.8/site-packages (from jina-hubble-sdk==0.33.1->finetuner[full]) (6.0)
# Requirement already satisfied: python-jose in ./.local/lib/python3.8/site-packages (from jina-hubble-sdk==0.33.1->finetuner[full]) (3.3.0)
# Requirement already satisfied: docker in ./.local/lib/python3.8/site-packages (from jina-hubble-sdk==0.33.1->finetuner[full]) (6.1.3)
# Requirement already satisfied: torch~=1.12.0 in ./.local/lib/python3.8/site-packages (from finetuner-commons==0.13.7; extra == "full"->finetuner[full]) (1.12.1)
# Requirement already satisfied: transformers==4.20.1 in ./.local/lib/python3.8/site-packages (from finetuner-commons==0.13.7; extra == "full"->finetuner[full]) (4.20.1)
# Requirement already satisfied: onnx>1.11.0 in ./.local/lib/python3.8/site-packages (from finetuner-commons==0.13.7; extra == "full"->finetuner[full]) (1.14.0)
# Requirement already satisfied: open-clip-torch==2.5.0 in ./.local/lib/python3.8/site-packages (from finetuner-commons==0.13.7; extra == "full"->finetuner[full]) (2.5.0)
# Requirement already satisfied: torchvision~=0.13.0 in ./.local/lib/python3.8/site-packages (from finetuner-commons==0.13.7; extra == "full"->finetuner[full]) (0.13.1)
# Requirement already satisfied: albumentations==1.2.0 in ./.local/lib/python3.8/site-packages (from finetuner-commons==0.13.7; extra == "full"->finetuner[full]) (1.2.0)
# Requirement already satisfied: onnxruntime>1.11.1 in ./.local/lib/python3.8/site-packages (from finetuner-commons==0.13.7; extra == "full"->finetuner[full]) (1.15.1)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.local/lib/python3.8/site-packages (from rich>=12.0.0->docarray[common]<0.30.0->finetuner[full]) (2.15.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.local/lib/python3.8/site-packages (from rich>=12.0.0->docarray[common]<0.30.0->finetuner[full]) (3.0.0)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in ./.local/lib/python3.8/site-packages (from fastapi; extra == "common"->docarray[common]<0.30.0->finetuner[full]) (0.27.0)
# Requirement already satisfied: h11>=0.8 in ./.local/lib/python3.8/site-packages (from uvicorn; extra == "common"->docarray[common]<0.30.0->finetuner[full]) (0.14.0)
# Requirement already satisfied: click>=7.0 in /usr/lib/python3/dist-packages (from uvicorn; extra == "common"->docarray[common]<0.30.0->finetuner[full]) (7.0)
# Requirement already satisfied: zipp>=0.5 in ./.local/lib/python3.8/site-packages (from importlib-metadata->jina-hubble-sdk==0.33.1->finetuner[full]) (3.15.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/lib/python3/dist-packages (from aiohttp->jina-hubble-sdk==0.33.1->finetuner[full]) (19.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.local/lib/python3.8/site-packages (from aiohttp->jina-hubble-sdk==0.33.1->finetuner[full]) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in ./.local/lib/python3.8/site-packages (from aiohttp->jina-hubble-sdk==0.33.1->finetuner[full]) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.local/lib/python3.8/site-packages (from aiohttp->jina-hubble-sdk==0.33.1->finetuner[full]) (1.3.3)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in ./.local/lib/python3.8/site-packages (from aiohttp->jina-hubble-sdk==0.33.1->finetuner[full]) (3.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.local/lib/python3.8/site-packages (from aiohttp->jina-hubble-sdk==0.33.1->finetuner[full]) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.local/lib/python3.8/site-packages (from aiohttp->jina-hubble-sdk==0.33.1->finetuner[full]) (1.9.2)
# Requirement already satisfied: rsa in /usr/lib/python3/dist-packages (from python-jose->jina-hubble-sdk==0.33.1->finetuner[full]) (4.0)
# Requirement already satisfied: pyasn1 in /usr/lib/python3/dist-packages (from python-jose->jina-hubble-sdk==0.33.1->finetuner[full]) (0.4.2)
# Requirement already satisfied: ecdsa!=0.15 in ./.local/lib/python3.8/site-packages (from python-jose->jina-hubble-sdk==0.33.1->finetuner[full]) (0.18.0)
# Requirement already satisfied: urllib3>=1.26.0 in ./.local/lib/python3.8/site-packages (from docker->jina-hubble-sdk==0.33.1->finetuner[full]) (2.0.3)
# Requirement already satisfied: packaging>=14.0 in ./.local/lib/python3.8/site-packages (from docker->jina-hubble-sdk==0.33.1->finetuner[full]) (23.1)
# Requirement already satisfied: websocket-client>=0.32.0 in ./.local/lib/python3.8/site-packages (from docker->jina-hubble-sdk==0.33.1->finetuner[full]) (1.6.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in ./.local/lib/python3.8/site-packages (from transformers==4.20.1->finetuner-commons==0.13.7; extra == "full"->finetuner[full]) (0.12.1)
# Requirement already satisfied: tqdm>=4.27 in ./.local/lib/python3.8/site-packages (from transformers==4.20.1->finetuner-commons==0.13.7; extra == "full"->finetuner[full]) (4.65.0)
# Requirement already satisfied: regex!=2019.12.17 in ./.local/lib/python3.8/site-packages (from transformers==4.20.1->finetuner-commons==0.13.7; extra == "full"->finetuner[full]) (2023.6.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in ./.local/lib/python3.8/site-packages (from transformers==4.20.1->finetuner-commons==0.13.7; extra == "full"->finetuner[full]) (0.15.1)
# Requirement already satisfied: ftfy in ./.local/lib/python3.8/site-packages (from open-clip-torch==2.5.0->finetuner-commons==0.13.7; extra == "full"->finetuner[full]) (6.1.1)
# Requirement already satisfied: scipy in ./.local/lib/python3.8/site-packages (from albumentations==1.2.0->finetuner-commons==0.13.7; extra == "full"->finetuner[full]) (1.10.1)
# Requirement already satisfied: scikit-image<0.19,>=0.16.1 in /usr/lib/python3/dist-packages (from albumentations==1.2.0->finetuner-commons==0.13.7; extra == "full"->finetuner[full]) (0.16.2)
# Requirement already satisfied: qudida>=0.0.4 in ./.local/lib/python3.8/site-packages (from albumentations==1.2.0->finetuner-commons==0.13.7; extra == "full"->finetuner[full]) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in ./.local/lib/python3.8/site-packages (from albumentations==1.2.0->finetuner-commons==0.13.7; extra == "full"->finetuner[full]) (4.7.0.72)
# Requirement already satisfied: flatbuffers in /usr/lib/python3/dist-packages (from onnxruntime>1.11.1->finetuner-commons==0.13.7; extra == "full"->finetuner[full]) (1.12)
# Requirement already satisfied: sympy in ./.local/lib/python3.8/site-packages (from onnxruntime>1.11.1->finetuner-commons==0.13.7; extra == "full"->finetuner[full]) (1.12)
# Requirement already satisfied: coloredlogs in ./.local/lib/python3.8/site-packages (from onnxruntime>1.11.1->finetuner-commons==0.13.7; extra == "full"->finetuner[full]) (15.0.1)
# Requirement already satisfied: mdurl~=0.1 in ./.local/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->docarray[common]<0.30.0->finetuner[full]) (0.1.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in ./.local/lib/python3.8/site-packages (from starlette<0.28.0,>=0.27.0->fastapi; extra == "common"->docarray[common]<0.30.0->finetuner[full]) (3.7.0)
# Requirement already satisfied: idna>=2.0 in /usr/lib/python3/dist-packages (from yarl<2.0,>=1.0->aiohttp->jina-hubble-sdk==0.33.1->finetuner[full]) (2.8)
# Requirement already satisfied: six>=1.9.0 in /usr/lib/python3/dist-packages (from ecdsa!=0.15->python-jose->jina-hubble-sdk==0.33.1->finetuner[full]) (1.14.0)
# Requirement already satisfied: fsspec in ./.local/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.20.1->finetuner-commons==0.13.7; extra == "full"->finetuner[full]) (2023.6.0)
# Requirement already satisfied: wcwidth>=0.2.5 in ./.local/lib/python3.8/site-packages (from ftfy->open-clip-torch==2.5.0->finetuner-commons==0.13.7; extra == "full"->finetuner[full]) (0.2.6)
# Requirement already satisfied: scikit-learn>=0.19.1 in ./.local/lib/python3.8/site-packages (from qudida>=0.0.4->albumentations==1.2.0->finetuner-commons==0.13.7; extra == "full"->finetuner[full]) (1.2.2)
# Requirement already satisfied: mpmath>=0.19 in ./.local/lib/python3.8/site-packages (from sympy->onnxruntime>1.11.1->finetuner-commons==0.13.7; extra == "full"->finetuner[full]) (1.3.0)
# Requirement already satisfied: humanfriendly>=9.1 in ./.local/lib/python3.8/site-packages (from coloredlogs->onnxruntime>1.11.1->finetuner-commons==0.13.7; extra == "full"->finetuner[full]) (10.0)
# Requirement already satisfied: exceptiongroup; python_version < "3.11" in ./.local/lib/python3.8/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi; extra == "common"->docarray[common]<0.30.0->finetuner[full]) (1.1.1)
# Requirement already satisfied: sniffio>=1.1 in ./.local/lib/python3.8/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi; extra == "common"->docarray[common]<0.30.0->finetuner[full]) (1.3.0)
# Requirement already satisfied: joblib>=1.1.1 in ./.local/lib/python3.8/site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations==1.2.0->finetuner-commons==0.13.7; extra == "full"->finetuner[full]) (1.3.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.local/lib/python3.8/site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations==1.2.0->finetuner-commons==0.13.7; extra == "full"->finetuner[full]) (3.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Task
# We'll be fine-tuning CLIP on the [fashion captioning dataset](https://github.com/xuewyang/Fashion_Captioning) which contains information about fashion products.
#
# For each product, the dataset contains a title and images of multiple variants of the product. We constructed a parent [`Document`](https://docarray.jina.ai/fundamentals/document/#document) for each picture, which contains two [chunks](https://docarray.jina.ai/fundamentals/document/nested/#nested-structure): an image document and a text document holding the description of the product.

# %% [markdown]
# ## Data
# Our journey starts locally. We have to [prepare the data and push it to the Jina AI Cloud](https://finetuner.jina.ai/walkthrough/create-training-data/) and Finetuner will be able to get the dataset by its name. For this example,
# we already prepared the data, and we'll provide the names of training and evaluation data (`fashion-train-data-clip` and `fashion-eval-data-clip`) directly to Finetuner.
# In addition, we also provide labeled queries and an index of labeled documents for evaluating the retrieval capabilities of the resulting fine-tuned model stored in the datasets `fashion-eval-data-queries` and `fashion-eval-data-index`.
#
#
# ```{admonition} Push data to the cloud
# We don't require you to push data to the Jina AI Cloud by yourself. Instead of a name, you can provide a `DocumentArray` and Finetuner will do the job for you.
# When working with documents where images are stored locally, please call `doc.load_uri_to_blob()` to reduce network transmission and speed up training.
# ```

# %%
import finetuner
from docarray import DocumentArray, Document

finetuner.login()
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.0.3) or chardet (5.1.0) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# VBox(children=(HTML(value="\n<div class='custom-container'>\n    <style>\n        .custom-container {\n       …

# %%
train_data = DocumentArray.pull('finetuner/fashion-train-data-clip', show_progress=True)
eval_data = DocumentArray.pull('finetuner/fashion-eval-data-clip', show_progress=True)
query_data = DocumentArray.pull('finetuner/fashion-eval-data-queries', show_progress=True)
index_data = DocumentArray.pull('finetuner/fashion-eval-data-index', show_progress=True)

train_data.summary()
# Out:
# 🔐 You are logged in to Jina AI as zhouxuanang63 (username: zhouxuanang63). To log out, use jina auth logout.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────── Documents Summary ─────────────────╮
# │                                                     │
# │   Type                      DocumentArrayInMemory   │
# │   Length                    12514                   │
# │   Homogenous Documents      True                    │
# │   Has nested Documents in   ('chunks',)             │
# │   Common Attributes         ('id', 'chunks')        │
# │   Multimodal dataclass      False                   │
# │                                                     │
# ╰─────────────────────────────────────────────────────╯
# ╭──────────────────────── Attributes Summary ────────────────────────╮
# │                                                                    │
# │   Attribute   Data type         #Unique values   Has empty value   │
# │  ────────────────────────────────────────────────────────────────  │
# │   chunks      ('ChunkArray',)   12514            False             │
# │   id          ('str',)          12514            False             │
# │                                                                    │
# ╰────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ## Backbone model
# Currently, we support several CLIP variations from [open-clip](https://github.com/mlfoundations/open_clip) for text to image retrieval tasks.
#
# However, you can see all available models either in [choose backbone](https://finetuner.jina.ai/walkthrough/choose-backbone/) section or by calling `finetuner.describe_models()`.

# %% [markdown]
# ## Fine-tuning
#
# Now that we have the training and evaluation datasets loaded as `DocumentArray`s and selected our model, we can start our fine-tuning run.

# %%
from finetuner.callback import EvaluationCallback

run = finetuner.fit(
    model='openai/clip-vit-base-patch32',
    train_data='finetuner/fashion-train-data-clip',
    eval_data='finetuner/fashion-eval-data-clip',
    epochs=5,
    learning_rate= 1e-7,
    loss='CLIPLoss',
    device='cuda',
    callbacks=[
        EvaluationCallback(
            model='clip-text',
            index_model='clip-vision',
            query_data='finetuner/fashion-eval-data-queries',
            index_data='finetuner/fashion-eval-data-index',
            gather_examples=True,
        )
    ],
)

# %% [markdown]
# Let's understand what this piece of code does:
#
# * We start with providing `model`, names of training and evaluation data.
# * We also provide some hyperparameters such as number of `epochs` and a `learning_rate`.
# * We use `CLIPLoss` to optimize the CLIP model.
# * We use an evaluation callback, which uses the `'clip-text'` model for encoding the text queries and the `'clip-vision'` model for encoding the images in `'fashion-eval-data-index'`.

# %%
import torch
print(torch.__version__)
if torch.cuda.is_available():
    print(torch.version.cuda)
else:
    print("CUDA is not available.")
# Out:
# 2.0.1+cu117
# 11.7

# %% [markdown]
# ## Monitoring
#
# Now that we've created a run, let's see its status. You can monitor the run by checking the status - `run.status()` and - the logs - `run.logs()` or - `run.stream_logs()`.

# %%
# note, the fine-tuning might takes 20~ minutes
for entry in run.stream_logs():
    print(entry)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [01:33:57] INFO     Starting finetuner training run ...                                                  __main__.py:350
# DEBUG    Found Jina AI Cloud authentication token                                             __main__.py:362
# DEBUG    Running in online mode                                                               __main__.py:363
# INFO     Reading config ...                                                                   __main__.py:370
# DEBUG    Reading config from stream                                                           __main__.py:382
# INFO     Parsing config ...                                                                   __main__.py:385
# INFO     Config loaded 📜                                                                     __main__.py:389
# INFO     Run name: crazy-engelbart                                                            __main__.py:391
# INFO     Experiment name: default                                                             __main__.py:392
# DEBUG    Device set to [cuda]                                                                 __main__.py:395
# DEBUG    Artifact ID set to 64a769d21d85b7938c8caf7f                                          __main__.py:141
# DEBUG    Artifact ID for metrics set to 64a769d31d85b7938c8caf80                              __main__.py:144
# DEBUG    Artifact ID for example results set to 64a769d31d85b7938c8caf81                      __main__.py:147
# INFO     Building the tuner components ...                                                    __main__.py:161
# INFO     Building models ...                                                                    tuning.py:326
# DEBUG    Model name: openai/clip-vit-base-patch32                                               tuning.py:328
# DEBUG    Model options: {}                                                                      tuning.py:329
# Downloading:   0%|          | 0.00/4.09k [00:00<?, ?B/s]
# Downloading: 100%|██████████| 4.09k/4.09k [00:00<00:00, 26.4MB/s]
# Downloading:   0%|          | 0.00/577M [00:00<?, ?B/s]
# Downloading:   1%|▏         | 7.52M/577M [00:00<00:07, 78.9MB/s]
# Downloading:   3%|▎         | 15.2M/577M [00:00<00:07, 80.0MB/s]
# Downloading:   4%|▍         | 23.0M/577M [00:00<00:07, 80.9MB/s]
# Downloading:   5%|▌         | 30.8M/577M [00:00<00:07, 81.3MB/s]
# Downloading:   7%|▋         | 38.6M/577M [00:00<00:06, 81.3MB/s]
# Downloading:   8%|▊         | 46.4M/577M [00:00<00:06, 81.4MB/s]
# Downloading:   9%|▉         | 54.3M/577M [00:00<00:06, 81.7MB/s]
# Downloading:  11%|█         | 62.0M/577M [00:00<00:06, 81.6MB/s]
# Downloading:  12%|█▏        | 69.8M/577M [00:00<00:06, 81.6MB/s]
# Downloading:  13%|█▎        | 77.6M/577M [00:01<00:06, 81.3MB/s]
# Downloading:  15%|█▍        | 85.4M/577M [00:01<00:06, 80.6MB/s]
# Downloading:  16%|█▌        | 93.2M/577M [00:01<00:06, 81.0MB/s]
# Downloading:  17%|█▋        | 101M/577M [00:01<00:06, 81.0MB/s]
# Downloading:  19%|█▉        | 109M/577M [00:01<00:06, 81.1MB/s]
# Downloading:  20%|██        | 116M/577M [00:01<00:05, 81.1MB/s]
# Downloading:  22%|██▏       | 124M/577M [00:01<00:05, 81.1MB/s]
# Downloading:  23%|██▎       | 132M/577M [00:01<00:05, 81.2MB/s]
# Downloading:  24%|██▍       | 140M/577M [00:01<00:05, 81.3MB/s]
# Downloading:  26%|██▌       | 147M/577M [00:01<00:05, 81.2MB/s]
# Downloading:  27%|██▋       | 155M/577M [00:02<00:05, 80.9MB/s]
# Downloading:  28%|██▊       | 163M/577M [00:02<00:05, 81.2MB/s]
# Downloading:  30%|██▉       | 171M/577M [00:02<00:05, 81.4MB/s]
# Downloading:  31%|███       | 179M/577M [00:02<00:05, 81.5MB/s]
# Downloading:  32%|███▏      | 186M/577M [00:02<00:05, 81.4MB/s]
# Downloading:  34%|███▎      | 194M/577M [00:02<00:04, 81.3MB/s]
# Downloading:  35%|███▍      | 202M/577M [00:02<00:04, 81.2MB/s]
# Downloading:  36%|███▋      | 210M/577M [00:02<00:04, 80.3MB/s]
# Downloading:  38%|███▊      | 218M/577M [00:02<00:04, 81.0MB/s]
# Downloading:  39%|███▉      | 225M/577M [00:02<00:04, 81.2MB/s]
# Downloading:  40%|████      | 233M/577M [00:03<00:04, 80.9MB/s]
# Downloading:  42%|████▏     | 241M/577M [00:03<00:04, 81.0MB/s]
# Downloading:  43%|████▎     | 249M/577M [00:03<00:04, 81.2MB/s]
# Downloading:  44%|████▍     | 256M/577M [00:03<00:04, 81.0MB/s]
# Downloading:  46%|████▌     | 264M/577M [00:03<00:04, 79.4MB/s]
# Downloading:  47%|████▋     | 272M/577M [00:03<00:04, 80.0MB/s]
# Downloading:  48%|████▊     | 280M/577M [00:03<00:03, 80.4MB/s]
# Downloading:  50%|████▉     | 287M/577M [00:03<00:03, 80.7MB/s]
# Downloading:  51%|█████     | 295M/577M [00:03<00:03, 80.8MB/s]
# Downloading:  52%|█████▏    | 303M/577M [00:03<00:03, 80.6MB/s]
# Downloading:  54%|█████▍    | 310M/577M [00:04<00:03, 80.5MB/s]
# Downloading:  55%|█████▌    | 318M/577M [00:04<00:03, 80.6MB/s]
# Downloading:  56%|█████▋    | 326M/577M [00:04<00:03, 80.7MB/s]
# Downloading:  58%|█████▊    | 334M/577M [00:04<00:03, 80.8MB/s]
# Downloading:  59%|█████▉    | 341M/577M [00:04<00:03, 80.8MB/s]
# Downloading:  60%|██████    | 349M/577M [00:04<00:02, 81.0MB/s]
# Downloading:  62%|██████▏   | 357M/577M [00:04<00:02, 81.1MB/s]
# Downloading:  63%|██████▎   | 365M/577M [00:04<00:02, 81.0MB/s]
# Downloading:  65%|██████▍   | 372M/577M [00:04<00:02, 81.0MB/s]
# Downloading:  66%|██████▌   | 380M/577M [00:04<00:02, 81.0MB/s]
# Downloading:  67%|██████▋   | 388M/577M [00:05<00:02, 81.0MB/s]
# Downloading:  69%|██████▊   | 396M/577M [00:05<00:02, 81.0MB/s]
# Downloading:  70%|██████▉   | 403M/577M [00:05<00:02, 81.0MB/s]
# Downloading:  71%|███████   | 411M/577M [00:05<00:02, 80.7MB/s]
# Downloading:  73%|███████▎  | 419M/577M [00:05<00:02, 80.5MB/s]
# Downloading:  74%|███████▍  | 426M/577M [00:05<00:01, 80.6MB/s]
# Downloading:  75%|███████▌  | 434M/577M [00:05<00:01, 80.5MB/s]
# Downloading:  77%|███████▋  | 442M/577M [00:05<00:01, 80.2MB/s]
# Downloading:  78%|███████▊  | 449M/577M [00:05<00:01, 79.9MB/s]
# Downloading:  79%|███████▉  | 457M/577M [00:05<00:01, 79.9MB/s]
# Downloading:  80%|████████  | 465M/577M [00:06<00:01, 79.9MB/s]
# Downloading:  82%|████████▏ | 472M/577M [00:06<00:01, 80.4MB/s]
# Downloading:  83%|████████▎ | 480M/577M [00:06<00:01, 80.6MB/s]
# Downloading:  85%|████████▍ | 488M/577M [00:06<00:01, 80.5MB/s]
# Downloading:  86%|████████▌ | 496M/577M [00:06<00:01, 80.5MB/s]
# Downloading:  87%|████████▋ | 503M/577M [00:06<00:00, 80.5MB/s]
# Downloading:  89%|████████▊ | 511M/577M [00:06<00:00, 80.7MB/s]
# Downloading:  90%|████████▉ | 519M/577M [00:06<00:00, 80.9MB/s]
# Downloading:  91%|█████████ | 526M/577M [00:06<00:00, 80.9MB/s]
# Downloading:  93%|█████████▎| 534M/577M [00:06<00:00, 80.7MB/s]
# Downloading:  94%|█████████▍| 542M/577M [00:07<00:00, 80.5MB/s]
# Downloading:  95%|█████████▌| 550M/577M [00:07<00:00, 80.7MB/s]
# Downloading:  97%|█████████▋| 557M/577M [00:07<00:00, 80.7MB/s]
# Downloading:  98%|█████████▊| 565M/577M [00:07<00:00, 80.9MB/s]
# Downloading:  99%|█████████▉| 573M/577M [00:07<00:00, 80.9MB/s]
# Downloading: 100%|██████████| 577M/577M [00:07<00:00, 80.8MB/s]
# Downloading:   0%|          | 0.00/568 [00:00<?, ?B/s]
# Downloading: 100%|██████████| 568/568 [00:00<00:00, 4.95MB/s]
# Downloading:   0%|          | 0.00/842k [00:00<?, ?B/s]
# Downloading: 100%|██████████| 842k/842k [00:00<00:00, 33.9MB/s]
# Downloading:   0%|          | 0.00/512k [00:00<?, ?B/s]
# Downloading:  19%|█▉        | 98.0k/512k [00:00<00:00, 559kB/s]
# Downloading: 100%|██████████| 512k/512k [00:00<00:00, 1.92MB/s]
# Downloading:   0%|          | 0.00/2.12M [00:00<?, ?B/s]
# Downloading:  75%|███████▌  | 1.60M/2.12M [00:00<00:00, 16.8MB/s]
# Downloading: 100%|██████████| 2.12M/2.12M [00:00<00:00, 20.9MB/s]
# Downloading:   0%|          | 0.00/389 [00:00<?, ?B/s]
# Downloading: 100%|██████████| 389/389 [00:00<00:00, 3.57MB/s]
# Downloading:   0%|          | 0.00/316 [00:00<?, ?B/s]
# Downloading: 100%|██████████| 316/316 [00:00<00:00, 2.61MB/s]
# [01:34:10] INFO     Loading the training data ...                                                          tuning.py:158
# INFO     Pulling data from cloud storage ...                                                      utils.py:80
# ping
# 2023-07-07 01:34:21.402159
# 🔐 You are logged in to Jina AI as zhouxuanang63 (username: zhouxuanang63). To log out, use jina auth logout.
# ping
# 2023-07-07 01:34:36.402603
# ping
# 2023-07-07 01:34:51.402644
# [01:34:42] DEBUG    Saving initial state of the model                                                    batchsize.py:86
# ping
# 2023-07-07 01:35:06.403360
# [01:35:03] DEBUG    Testing batch size of 8                                                             batchsize.py:122
# [01:35:04] DEBUG    Testing batch size of 16                                                            batchsize.py:122
# DEBUG    Testing batch size of 32                                                            batchsize.py:122
# [01:35:05] DEBUG    Testing batch size of 64                                                            batchsize.py:122
# Traceback (most recent call last):
# File "/usr/local/lib/python3.8/multiprocessing/queues.py", line 245, in _feed
# send_bytes(obj)
# File "/usr/local/lib/python3.8/multiprocessing/connection.py", line 200, in send_bytes
# self._send_bytes(m[offset:offset + size])
# File "/usr/local/lib/python3.8/multiprocessing/connection.py", line 411, in _send_bytes
# self._send(header + buf)
# File "/usr/local/lib/python3.8/multiprocessing/connection.py", line 368, in _send
# n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# [01:35:06] DEBUG    Testing batch size of 128                                                           batchsize.py:122
# [01:35:08] DEBUG    Testing batch size of 256                                                           batchsize.py:122
# [01:35:10] DEBUG    Testing batch size of 512                                                           batchsize.py:122
# ping
# 2023-07-07 01:35:21.403849
# [01:35:14] DEBUG    Batch_size adjusted from 4 to 256                                                    batchsize.py:91
# DEBUG    Restoring initial state of the model                                                 batchsize.py:93
# INFO     Loading the evaluation data ...                                                        tuning.py:255
# INFO     Pulling data from cloud storage ...                                                      utils.py:80
# Deserializing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 787/787 • 547 QPS • 0:00:00 • 20.3 MB
# [01:35:19] DEBUG    # eval samples: 787                                                                    tuning.py:262
# INFO     Building loss ...                                                                      tuning.py:431
# DEBUG    Loss name: CLIPLoss                                                                    tuning.py:432
# DEBUG    Loss options: {}                                                                       tuning.py:433
# INFO     Building optimizer ...                                                                 tuning.py:538
# DEBUG    Optimizer name: Adam                                                                   tuning.py:539
# DEBUG    Optimizer options: {'lr': 1e-07}                                                       tuning.py:540
# INFO     Building callback 'EvaluationCallback' ...                                             tuning.py:815
# DEBUG    Callback options: {'query_data': 'finetuner/fashion-eval-data-queries', 'index_data':  tuning.py:816
# 'finetuner/fashion-eval-data-index', 'model': 'clip-text', 'index_model':
# 'clip-vision', 'multi_modal': False, 'batch_size': 32, 'exclude_self': True, 'limit':
# 20, 'distance': 'cosine', 'steps_per_interval': None, 'gather_examples': True,
# 'num_example_queries': 5, 'num_workers': 8, 'caption': None, 'output_model_names':
# False, 'query_sample_size': None}
# INFO     Loading the query data ...                                                             tuning.py:646
# INFO     Pulling data from cloud storage ...                                                      utils.py:80
# Deserializing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 787/787 • 12103 QPS • 0:00:00 • 119.1 kB
# [01:35:22] INFO     Loading the index data ...                                                             tuning.py:654
# INFO     Pulling data from cloud storage ...                                                      utils.py:80
# ping
# 2023-07-07 01:35:36.404551
# Deserializing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 787/787 • 554 QPS • 0:00:00 • 20.2 MB
# [01:35:26] DEBUG    # index samples: 787                                                                   tuning.py:659
# INFO     Model, data, callbacks, loss, miner and optimizer built successfully 🔥              __main__.py:165
# INFO     Finetuning ...                                                                       __main__.py:170
# [01:35:30] DEBUG    Evaluation result at epoch: 0/5 is:                                                evaluation.py:387
# DEBUG    Metric: 'precision_at_k' Value: 0.01144                                            evaluation.py:389
# DEBUG    Metric: 'recall_at_k' Value: 0.02414                                               evaluation.py:389
# DEBUG    Metric: 'f1_score_at_k' Value: 0.01429                                             evaluation.py:389
# DEBUG    Metric: 'hit_at_k' Value: 0.16645                                                  evaluation.py:389
# DEBUG    Metric: 'average_precision' Value: 0.07557                                         evaluation.py:389
# DEBUG    Metric: 'reciprocal_rank' Value: 0.07860                                           evaluation.py:389
# DEBUG    Metric: 'dcg_at_k' Value: 0.12840                                                  evaluation.py:389
# DEBUG    Example results at epoch: 0/5:                                                     evaluation.py:255
# DEBUG    Query: cotswold crewneck wool sweater                                              evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/b410acac-77d1-4253-9063-5de893dc80fa.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/70aad537-e8fc-4585-b72d-5524d64b5302.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/5936bc00-8283-4bb1-af8a-49db3362704c.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: gideon satin romper                                                         evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/b410acac-77d1-4253-9063-5de893dc80fa.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/70aad537-e8fc-4585-b72d-5524d64b5302.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/9c3681b0-79ba-4751-9dc8-1b1cb18bcf82.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: puff sleeve cotton crop top                                                 evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/70aad537-e8fc-4585-b72d-5524d64b5302.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/5936bc00-8283-4bb1-af8a-49db3362704c.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/6f3ec919-b0ac-436b-af94-cc90c82c698c.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: nuage metallic dot silk blend midi dress                                    evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/b410acac-77d1-4253-9063-5de893dc80fa.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/9c3681b0-79ba-4751-9dc8-1b1cb18bcf82.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/70aad537-e8fc-4585-b72d-5524d64b5302.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: eme leather crossbody bag                                                   evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/6f3ec919-b0ac-436b-af94-cc90c82c698c.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/70aad537-e8fc-4585-b72d-5524d64b5302.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/5936bc00-8283-4bb1-af8a-49db3362704c.jpeg?crop
# =pad&pad_color=FFF...
# ping
# 2023-07-07 01:35:51.403862
# ping
# 2023-07-07 01:36:06.404846
# ping
# 2023-07-07 01:36:21.405487
# [01:36:17] DEBUG    Evaluation result at epoch: 1/5 is:                                                evaluation.py:404
# DEBUG    Metric: 'precision_at_k' Value: 0.01658                                            evaluation.py:406
# DEBUG    Metric: 'recall_at_k' Value: 0.03050                                               evaluation.py:406
# DEBUG    Metric: 'f1_score_at_k' Value: 0.01977                                             evaluation.py:406
# DEBUG    Metric: 'hit_at_k' Value: 0.25667                                                  evaluation.py:406
# DEBUG    Metric: 'average_precision' Value: 0.04917                                         evaluation.py:406
# DEBUG    Metric: 'reciprocal_rank' Value: 0.05977                                           evaluation.py:406
# DEBUG    Metric: 'dcg_at_k' Value: 0.13451                                                  evaluation.py:406
# DEBUG                                                                                       evaluation.py:407
# DEBUG    Example results at epoch: 1/5:                                                     evaluation.py:255
# DEBUG    Query: cotswold crewneck wool sweater                                              evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/665b1666-f74c-477f-8d59-6b5b602ad438.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/b410acac-77d1-4253-9063-5de893dc80fa.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/582151ed-0837-473f-9791-a398b0cffe41.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: gideon satin romper                                                         evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/665b1666-f74c-477f-8d59-6b5b602ad438.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/957ce16f-8322-448f-b31e-df7a2b72b9d7.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/b410acac-77d1-4253-9063-5de893dc80fa.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: puff sleeve cotton crop top                                                 evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/665b1666-f74c-477f-8d59-6b5b602ad438.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/b410acac-77d1-4253-9063-5de893dc80fa.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/9c3681b0-79ba-4751-9dc8-1b1cb18bcf82.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: nuage metallic dot silk blend midi dress                                    evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/665b1666-f74c-477f-8d59-6b5b602ad438.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/582151ed-0837-473f-9791-a398b0cffe41.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/b410acac-77d1-4253-9063-5de893dc80fa.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: eme leather crossbody bag                                                   evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/6f3ec919-b0ac-436b-af94-cc90c82c698c.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/665b1666-f74c-477f-8d59-6b5b602ad438.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/70aad537-e8fc-4585-b72d-5524d64b5302.jpeg?crop
# =pad&pad_color=FFF...
# ping
# 2023-07-07 01:36:36.405228
# ping
# 2023-07-07 01:36:51.405588
# ping
# 2023-07-07 01:37:06.404920
# [01:37:03] DEBUG    Evaluation result at epoch: 2/5 is:                                                evaluation.py:404
# DEBUG    Metric: 'precision_at_k' Value: 0.01645                                            evaluation.py:406
# DEBUG    Metric: 'recall_at_k' Value: 0.02922                                               evaluation.py:406
# DEBUG    Metric: 'f1_score_at_k' Value: 0.01932                                             evaluation.py:406
# DEBUG    Metric: 'hit_at_k' Value: 0.25413                                                  evaluation.py:406
# DEBUG    Metric: 'average_precision' Value: 0.05250                                         evaluation.py:406
# DEBUG    Metric: 'reciprocal_rank' Value: 0.06221                                           evaluation.py:406
# DEBUG    Metric: 'dcg_at_k' Value: 0.14732                                                  evaluation.py:406
# DEBUG                                                                                       evaluation.py:407
# DEBUG    Example results at epoch: 2/5:                                                     evaluation.py:255
# DEBUG    Query: cotswold crewneck wool sweater                                              evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/957ce16f-8322-448f-b31e-df7a2b72b9d7.jpeg?crop
# =pad&pad_color=FFF...
# [01:37:04] DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/665b1666-f74c-477f-8d59-6b5b602ad438.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: gideon satin romper                                                         evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/957ce16f-8322-448f-b31e-df7a2b72b9d7.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/665b1666-f74c-477f-8d59-6b5b602ad438.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: puff sleeve cotton crop top                                                 evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/665b1666-f74c-477f-8d59-6b5b602ad438.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/957ce16f-8322-448f-b31e-df7a2b72b9d7.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: nuage metallic dot silk blend midi dress                                    evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/957ce16f-8322-448f-b31e-df7a2b72b9d7.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/665b1666-f74c-477f-8d59-6b5b602ad438.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: eme leather crossbody bag                                                   evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/633215f6-7860-4192-8c8c-a48f9e77d95f.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/950fc558-3c27-482a-93d4-0f3bba35189d.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/e21d0e75-f0e5-41b1-895d-154e7851526b.jpeg?crop
# =pad&pad_color=FFF...
# ping
# 2023-07-07 01:37:21.405514
# ping
# 2023-07-07 01:37:36.405070
# ping
# 2023-07-07 01:37:51.404867
# [01:37:50] DEBUG    Evaluation result at epoch: 3/5 is:                                                evaluation.py:404
# DEBUG    Metric: 'precision_at_k' Value: 0.02027                                            evaluation.py:406
# DEBUG    Metric: 'recall_at_k' Value: 0.03558                                               evaluation.py:406
# DEBUG    Metric: 'f1_score_at_k' Value: 0.02348                                             evaluation.py:406
# DEBUG    Metric: 'hit_at_k' Value: 0.31766                                                  evaluation.py:406
# DEBUG    Metric: 'average_precision' Value: 0.04961                                         evaluation.py:406
# DEBUG    Metric: 'reciprocal_rank' Value: 0.05381                                           evaluation.py:406
# DEBUG    Metric: 'dcg_at_k' Value: 0.14411                                                  evaluation.py:406
# DEBUG                                                                                       evaluation.py:407
# DEBUG    Example results at epoch: 3/5:                                                     evaluation.py:255
# DEBUG    Query: cotswold crewneck wool sweater                                              evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/266f7e66-13e1-49eb-8bc8-1a7f64f1658a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/957ce16f-8322-448f-b31e-df7a2b72b9d7.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: gideon satin romper                                                         evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/665b1666-f74c-477f-8d59-6b5b602ad438.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/dc4007f9-558f-4e21-9791-3ec2ccf5cd99.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: puff sleeve cotton crop top                                                 evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/665b1666-f74c-477f-8d59-6b5b602ad438.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/950fc558-3c27-482a-93d4-0f3bba35189d.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: nuage metallic dot silk blend midi dress                                    evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/665b1666-f74c-477f-8d59-6b5b602ad438.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/957ce16f-8322-448f-b31e-df7a2b72b9d7.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: eme leather crossbody bag                                                   evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/633215f6-7860-4192-8c8c-a48f9e77d95f.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/950fc558-3c27-482a-93d4-0f3bba35189d.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/8ee5237c-dae6-4fd7-a551-0df9d9ade9e4.jpeg?crop
# =pad&pad_color=FFF...
# ping
# 2023-07-07 01:38:06.405839
# ping
# 2023-07-07 01:38:21.405898
# ping
# 2023-07-07 01:38:36.406176
# [01:38:36] DEBUG    Evaluation result at epoch: 4/5 is:                                                evaluation.py:404
# DEBUG    Metric: 'precision_at_k' Value: 0.02008                                            evaluation.py:406
# DEBUG    Metric: 'recall_at_k' Value: 0.03685                                               evaluation.py:406
# DEBUG    Metric: 'f1_score_at_k' Value: 0.02358                                             evaluation.py:406
# DEBUG    Metric: 'hit_at_k' Value: 0.29860                                                  evaluation.py:406
# DEBUG    Metric: 'average_precision' Value: 0.05169                                         evaluation.py:406
# DEBUG    Metric: 'reciprocal_rank' Value: 0.05602                                           evaluation.py:406
# DEBUG    Metric: 'dcg_at_k' Value: 0.14839                                                  evaluation.py:406
# DEBUG                                                                                       evaluation.py:407
# DEBUG    Example results at epoch: 4/5:                                                     evaluation.py:255
# DEBUG    Query: cotswold crewneck wool sweater                                              evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/266f7e66-13e1-49eb-8bc8-1a7f64f1658a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/d8fd48c0-e9a4-49f5-85ce-0f9c34706814.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: gideon satin romper                                                         evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/dc4007f9-558f-4e21-9791-3ec2ccf5cd99.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/950fc558-3c27-482a-93d4-0f3bba35189d.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: puff sleeve cotton crop top                                                 evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/950fc558-3c27-482a-93d4-0f3bba35189d.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/dc4007f9-558f-4e21-9791-3ec2ccf5cd99.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: nuage metallic dot silk blend midi dress                                    evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/266f7e66-13e1-49eb-8bc8-1a7f64f1658a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/665b1666-f74c-477f-8d59-6b5b602ad438.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: eme leather crossbody bag                                                   evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/633215f6-7860-4192-8c8c-a48f9e77d95f.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/30126a97-fda1-4b44-8ec8-d5d790e37e4b.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/8ee5237c-dae6-4fd7-a551-0df9d9ade9e4.jpeg?crop
# =pad&pad_color=FFF...
# ping
# 2023-07-07 01:38:51.406082
# ping
# 2023-07-07 01:39:06.405998
# ping
# 2023-07-07 01:39:21.406452
# [01:39:23] DEBUG    Evaluation result at epoch: 5/5 is:                                                evaluation.py:404
# DEBUG    Metric: 'precision_at_k' Value: 0.01919                                            evaluation.py:406
# DEBUG    Metric: 'recall_at_k' Value: 0.03558                                               evaluation.py:406
# DEBUG    Metric: 'f1_score_at_k' Value: 0.02248                                             evaluation.py:406
# DEBUG    Metric: 'hit_at_k' Value: 0.27446                                                  evaluation.py:406
# DEBUG    Metric: 'average_precision' Value: 0.05717                                         evaluation.py:406
# DEBUG    Metric: 'reciprocal_rank' Value: 0.06637                                           evaluation.py:406
# DEBUG    Metric: 'dcg_at_k' Value: 0.16185                                                  evaluation.py:406
# DEBUG                                                                                       evaluation.py:407
# DEBUG    Example results at epoch: 5/5:                                                     evaluation.py:255
# DEBUG    Query: cotswold crewneck wool sweater                                              evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/d8fd48c0-e9a4-49f5-85ce-0f9c34706814.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/266f7e66-13e1-49eb-8bc8-1a7f64f1658a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: gideon satin romper                                                         evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/ca51586d-d1df-4f8b-9c56-69eb0739a696.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/a79a9c88-ee23-46a8-99e7-08f699da9377.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: puff sleeve cotton crop top                                                 evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/dc4007f9-558f-4e21-9791-3ec2ccf5cd99.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/8f0b4779-4afa-4e80-86e4-8e23d2cc6a76.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: nuage metallic dot silk blend midi dress                                    evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/266f7e66-13e1-49eb-8bc8-1a7f64f1658a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/dc4007f9-558f-4e21-9791-3ec2ccf5cd99.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: eme leather crossbody bag                                                   evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/633215f6-7860-4192-8c8c-a48f9e77d95f.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/30126a97-fda1-4b44-8ec8-d5d790e37e4b.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/8ee5237c-dae6-4fd7-a551-0df9d9ade9e4.jpeg?crop
# =pad&pad_color=FFF...
# Training [5/5] ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97/97 0:00:00 0:00:40 • loss: 5.507 • val_loss: 5.514
# INFO     Done ✨                                                                              __main__.py:192
# DEBUG    Finetuning took 0 days, 0 hours 3 minutes and 57 seconds                             __main__.py:194
# INFO     Metric: 'precision_at_k' before fine-tuning:  0.01144 after fine-tuning: 0.01919     __main__.py:207
# INFO     Metric: 'recall_at_k' before fine-tuning:  0.02414 after fine-tuning: 0.03558        __main__.py:207
# INFO     Metric: 'f1_score_at_k' before fine-tuning:  0.01429 after fine-tuning: 0.02248      __main__.py:207
# INFO     Metric: 'hit_at_k' before fine-tuning:  0.16645 after fine-tuning: 0.27446           __main__.py:207
# INFO     Metric: 'average_precision' before fine-tuning:  0.07557 after fine-tuning: 0.05717  __main__.py:207
# INFO     Metric: 'reciprocal_rank' before fine-tuning:  0.07860 after fine-tuning: 0.06637    __main__.py:207
# INFO     Metric: 'dcg_at_k' before fine-tuning:  0.12840 after fine-tuning: 0.16185           __main__.py:207
# INFO     Example results for query: 'cotswold crewneck wool sweater':                         __main__.py:224
# INFO     Before fine-tuning:                                                                  __main__.py:227
# INFO     1:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/b410acac-77d1-4253-9063-5de893dc80fa.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     2:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/70aad537-e8fc-4585-b72d-5524d64b5302.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     3:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/5936bc00-8283-4bb1-af8a-49db3362704c.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     After fine-tuning:                                                                   __main__.py:227
# INFO     1:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     2:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/d8fd48c0-e9a4-49f5-85ce-0f9c34706814.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     3:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/266f7e66-13e1-49eb-8bc8-1a7f64f1658a.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     Example results for query: 'gideon satin romper':                                    __main__.py:224
# INFO     Before fine-tuning:                                                                  __main__.py:227
# INFO     1:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/b410acac-77d1-4253-9063-5de893dc80fa.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     2:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/70aad537-e8fc-4585-b72d-5524d64b5302.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     3:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/9c3681b0-79ba-4751-9dc8-1b1cb18bcf82.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     After fine-tuning:                                                                   __main__.py:227
# INFO     1:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/ca51586d-d1df-4f8b-9c56-69eb0739a696.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     2:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     3:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/a79a9c88-ee23-46a8-99e7-08f699da9377.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     Example results for query: 'puff sleeve cotton crop top':                            __main__.py:224
# INFO     Before fine-tuning:                                                                  __main__.py:227
# INFO     1:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/70aad537-e8fc-4585-b72d-5524d64b5302.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     2:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/5936bc00-8283-4bb1-af8a-49db3362704c.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# [01:39:24] INFO     3:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/6f3ec919-b0ac-436b-af94-cc90c82c698c.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     After fine-tuning:                                                                   __main__.py:227
# INFO     1:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     2:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/dc4007f9-558f-4e21-9791-3ec2ccf5cd99.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     3:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/8f0b4779-4afa-4e80-86e4-8e23d2cc6a76.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     Example results for query: 'nuage metallic dot silk blend midi dress':               __main__.py:224
# INFO     Before fine-tuning:                                                                  __main__.py:227
# INFO     1:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/b410acac-77d1-4253-9063-5de893dc80fa.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     2:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/9c3681b0-79ba-4751-9dc8-1b1cb18bcf82.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     3:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/70aad537-e8fc-4585-b72d-5524d64b5302.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     After fine-tuning:                                                                   __main__.py:227
# INFO     1:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     2:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/266f7e66-13e1-49eb-8bc8-1a7f64f1658a.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     3:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/dc4007f9-558f-4e21-9791-3ec2ccf5cd99.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     Example results for query: 'eme leather crossbody bag':                              __main__.py:224
# INFO     Before fine-tuning:                                                                  __main__.py:227
# INFO     1:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/6f3ec919-b0ac-436b-af94-cc90c82c698c.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     2:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/70aad537-e8fc-4585-b72d-5524d64b5302.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     3:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/5936bc00-8283-4bb1-af8a-49db3362704c.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     After fine-tuning:                                                                   __main__.py:227
# INFO     1:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/633215f6-7860-4192-8c8c-a48f9e77d95f.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     2:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/30126a97-fda1-4b44-8ec8-d5d790e37e4b.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     3:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/8ee5237c-dae6-4fd7-a551-0df9d9ade9e4.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     Building the artifact ...                                                            __main__.py:231
# INFO     Pushing artifact to Jina AI Cloud ...                                                __main__.py:260
# ping
# 2023-07-07 01:39:36.406108
# ping
# 2023-07-07 01:39:51.406593
# ping
# 2023-07-07 01:40:06.406302
# ping
# 2023-07-07 01:40:21.406297
# ping
# 2023-07-07 01:40:36.406234
# ping
# 2023-07-07 01:40:51.406295
# ping
# 2023-07-07 01:41:06.406372
# [01:41:12] INFO     Artifact pushed under ID '64a769d21d85b7938c8caf7f'                                  __main__.py:266
# DEBUG    Artifact size is 535.392 MB                                                          __main__.py:268
# INFO     Finished 🚀                                                                          __main__.py:415
# ping
# 2023-07-07 01:41:21.406801
# time="2023-07-07T01:41:15.112Z" level=info msg="sub-process exited" argo=true error="<nil>"

# %% [markdown]
# Since some runs might take up to several hours/days, it's important to know how to reconnect to Finetuner and retrieve your run.
#
# ```python
# import finetuner
#
# finetuner.login()
# run = finetuner.get_run(run.name)
# ```
#
# You can continue monitoring the run by checking the status - `finetuner.run.Run.status()` or the logs - `finetuner.run.Run.logs()`.

# %% [markdown]
# ## Evaluating
#
# Our `EvaluationCallback` during fine-tuning ensures that after each epoch, an evaluation of our model is run. We can access the results of the last evaluation in the logs as follows `print(run.logs())`:
#
# ```bash
#   Training [5/5] ━━━━ 195/195 0:00… 0:0… • loss: 2.419 • val_loss: 2.803
# [13:32:41] INFO     Done ✨                              __main__.py:195
#            DEBUG    Finetuning took 0 days, 0 hours 5 minutes and 30 seconds
#            DEBUG    Metric: 'clip-text-to-clip-vision_precision_at_k' Value: 0.28532
#            DEBUG    Metric: 'clip-text-to-clip-vision_hit_at_k' Value: 0.94282
#            DEBUG    Metric: 'clip-text-to-clip-vision_average_precision' Value: 0.53372
#            DEBUG    Metric: 'clip-text-to-clip-vision_reciprocal_rank' Value: 0.67706
#            DEBUG    Metric: 'clip-text-to-clip-vision_dcg_at_k' Value: 2.71247
# ...
# ```

# %% [markdown]
# ## Saving
#
# After the run has finished successfully, you can download the tuned model on your local machine:

# %%
artifact = run.save_artifact('clip-model')
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# ## Inference
#
# Now you saved the `artifact` into your host machine,
# let's use the fine-tuned model to encode a new `Document`:

# %%
pip install --upgrade torch
# Out:
# Collecting torch
#   Using cached torch-2.0.1-cp38-cp38-manylinux1_x86_64.whl (619.9 MB)
# Requirement already satisfied, skipping upgrade: nvidia-curand-cu11==10.2.10.91; platform_system == "Linux" and platform_machine == "x86_64" in ./.local/lib/python3.8/site-packages (from torch) (10.2.10.91)
# Requirement already satisfied, skipping upgrade: nvidia-cusparse-cu11==11.7.4.91; platform_system == "Linux" and platform_machine == "x86_64" in ./.local/lib/python3.8/site-packages (from torch) (11.7.4.91)
# Requirement already satisfied, skipping upgrade: networkx in /usr/lib/python3/dist-packages (from torch) (2.4)
# Requirement already satisfied, skipping upgrade: nvidia-cuda-cupti-cu11==11.7.101; platform_system == "Linux" and platform_machine == "x86_64" in ./.local/lib/python3.8/site-packages (from torch) (11.7.101)
# Requirement already satisfied, skipping upgrade: nvidia-cufft-cu11==10.9.0.58; platform_system == "Linux" and platform_machine == "x86_64" in ./.local/lib/python3.8/site-packages (from torch) (10.9.0.58)
# Requirement already satisfied, skipping upgrade: nvidia-cuda-runtime-cu11==11.7.99; platform_system == "Linux" and platform_machine == "x86_64" in ./.local/lib/python3.8/site-packages (from torch) (11.7.99)
# Requirement already satisfied, skipping upgrade: nvidia-cudnn-cu11==8.5.0.96; platform_system == "Linux" and platform_machine == "x86_64" in ./.local/lib/python3.8/site-packages (from torch) (8.5.0.96)
# Requirement already satisfied, skipping upgrade: nvidia-cublas-cu11==11.10.3.66; platform_system == "Linux" and platform_machine == "x86_64" in ./.local/lib/python3.8/site-packages (from torch) (11.10.3.66)
# Requirement already satisfied, skipping upgrade: filelock in /usr/lib/python3/dist-packages (from torch) (3.0.12)
# Requirement already satisfied, skipping upgrade: jinja2 in /usr/lib/python3/dist-packages (from torch) (2.10.1)
# Requirement already satisfied, skipping upgrade: nvidia-cuda-nvrtc-cu11==11.7.99; platform_system == "Linux" and platform_machine == "x86_64" in ./.local/lib/python3.8/site-packages (from torch) (11.7.99)
# Requirement already satisfied, skipping upgrade: nvidia-cusolver-cu11==11.4.0.1; platform_system == "Linux" and platform_machine == "x86_64" in ./.local/lib/python3.8/site-packages (from torch) (11.4.0.1)
# Requirement already satisfied, skipping upgrade: nvidia-nvtx-cu11==11.7.91; platform_system == "Linux" and platform_machine == "x86_64" in ./.local/lib/python3.8/site-packages (from torch) (11.7.91)
# Requirement already satisfied, skipping upgrade: typing-extensions in ./.local/lib/python3.8/site-packages (from torch) (4.5.0)
# Requirement already satisfied, skipping upgrade: triton==2.0.0; platform_system == "Linux" and platform_machine == "x86_64" in ./.local/lib/python3.8/site-packages (from torch) (2.0.0)
# Requirement already satisfied, skipping upgrade: nvidia-nccl-cu11==2.14.3; platform_system == "Linux" and platform_machine == "x86_64" in ./.local/lib/python3.8/site-packages (from torch) (2.14.3)
# Requirement already satisfied, skipping upgrade: sympy in ./.local/lib/python3.8/site-packages (from torch) (1.12)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/lib/python3/dist-packages (from nvidia-curand-cu11==10.2.10.91; platform_system == "Linux" and platform_machine == "x86_64"->torch) (45.2.0)
# Requirement already satisfied, skipping upgrade: wheel in /usr/lib/python3/dist-packages (from nvidia-curand-cu11==10.2.10.91; platform_system == "Linux" and platform_machine == "x86_64"->torch) (0.34.2)
# Requirement already satisfied, skipping upgrade: lit in ./.local/lib/python3.8/site-packages (from triton==2.0.0; platform_system == "Linux" and platform_machine == "x86_64"->torch) (16.0.6)
# Requirement already satisfied, skipping upgrade: cmake in ./.local/lib/python3.8/site-packages (from triton==2.0.0; platform_system == "Linux" and platform_machine == "x86_64"->torch) (3.26.4)
# Requirement already satisfied, skipping upgrade: mpmath>=0.19 in ./.local/lib/python3.8/site-packages (from sympy->torch) (1.3.0)
# ERROR: torchvision 0.13.1 has requirement torch==1.12.1, but you'll have torch 2.0.1 which is incompatible.
# ERROR: finetuner-commons 0.13.7 has requirement torch~=1.12.0, but you'll have torch 2.0.1 which is incompatible.
# ERROR: clip-benchmark 0.1.0 has requirement torch~=1.12.0, but you'll have torch 2.0.1 which is incompatible.
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1
#     Uninstalling torch-1.12.1:
#       Successfully uninstalled torch-1.12.1
# Successfully installed torch-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
text_da = DocumentArray([Document(text='It is power plant')])
image_da = DocumentArray([Document(uri='https://upload.wikimedia.org/wikipedia/commons/4/4e/Single_apple.png')])

clip_text_encoder = finetuner.get_model(artifact=artifact, select_model='clip-text')
clip_image_encoder = finetuner.get_model(artifact=artifact, select_model='clip-vision')

finetuner.encode(model=clip_text_encoder, data=text_da)
finetuner.encode(model=clip_image_encoder, data=image_da)

print(text_da.embeddings.shape)
print(image_da.embeddings.shape)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# (1, 512)
# (1, 512)

# %%
text_da.embeddings /= text_da.embeddings.norm(dim=-1, keepdim=True)
image_da.embeddings /= image_da.embeddings.norm(dim=-1, keepdim=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-da68c3154321> in <module>
# ----> 1 text_da.embeddings /= text_da.embeddings.norm(dim=-1, keepdim=True)
#       2 image_da.embeddings /= image_da.embeddings.norm(dim=-1, keepdim=True)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'norm'

# %%
text_probs = (100.0 * text_da.embeddings @ image_da.embeddings.T)
text_probs
# Out:
# array([[751.84436]], dtype=float32)

# %%
text_da.embeddings[0]
# Out:
# array([ 0.14375383, -0.26906556, -0.38438827,  0.36206883,  0.69655395,
#        -0.81428444, -0.16516723, -0.23125274,  0.08986352,  0.58297646,
#        -0.02588589,  0.12189655,  0.4983704 , -0.17940801, -0.10751052,
#         0.20987643, -0.12659965, -0.05431721,  0.18536851,  0.20650795,
#         0.08962855,  0.08575428,  0.35783172, -0.06759955,  0.41616726,
#        -0.1055069 , -0.21548906, -0.0103578 , -0.22008169,  0.26632747,
#        -0.08721125,  0.37607425, -0.10474437,  0.22722149,  0.53499335,
#         0.49934587,  0.13792686, -0.24344896, -0.16104543, -0.27879333,
#         0.17187774, -0.4938864 , -0.17419139,  0.10711716, -0.10188973,
#         0.00423103,  0.04693781,  0.13497007, -0.07911652, -0.11189476,
#        -0.22455178, -0.14007813,  0.05697646, -0.27160236,  0.07455105,
#        -0.26442477, -0.33530015, -0.03137265, -0.50789994, -0.05291897,
#        -0.40879315,  0.15830436, -0.0655795 ,  0.5527882 , -0.10715763,
#         0.06505173, -0.23504421, -0.40154856,  0.18645209,  0.05307834,
#         0.47133547, -0.11546873,  0.17201272, -0.0389585 ,  0.0386705 ,
#        -0.30562067, -0.51665646, -0.17438221,  0.40163442, -0.11217421,
#         0.13253236, -0.07697868, -0.10608958,  0.28098243, -0.1680988 ,
#        -0.01165328,  0.05647589, -0.03528657,  0.21782288,  0.09672891,
#        -0.14102633, -0.40164563, -1.099757  ,  0.17863382, -0.4367341 ,
#        -0.13318732,  0.37539247, -0.18284203, -0.41417015,  0.07912917,
#         0.06773682, -0.04492424,  0.0488423 ,  0.13635054,  0.1296106 ,
#        -0.08549513, -0.11057727,  0.2248024 ,  0.13285415, -0.37421644,
#         0.04493938,  0.29605135, -0.11415617, -0.20624594, -0.02289204,
#        -0.3763225 , -0.5841804 ,  0.2159254 , -0.08241877,  0.5761085 ,
#        -0.32352516, -0.03266288, -0.17437232,  0.08046529, -0.19300273,
#         0.0523836 ,  0.4597767 ,  0.2293632 ,  0.02564881,  0.7916661 ,
#        -0.14966354,  0.09492853,  0.42182136, -0.71757925, -0.14958745,
#         0.01205151, -0.0277545 , -0.6245446 ,  0.1213347 ,  0.05833833,
#         0.06058851,  0.34282178, -0.33763143, -0.38677844,  0.00596901,
#         0.16205171,  0.08588161, -0.36950463,  0.13893634, -0.1677098 ,
#         0.07183757,  0.127976  , -0.0826102 , -0.34366018, -0.2697031 ,
#         0.13243723,  0.00630553, -0.38384163,  0.20812745, -0.02016876,
#        -0.00661346, -0.04729947, -0.08377247,  0.0087072 , -0.261537  ,
#         0.551284  , -0.33216643,  0.05344286, -0.3093446 , -0.3383734 ,
#        -0.27161676, -0.14522374, -0.00887921, -0.53620005,  0.05911058,
#         0.10591082,  0.17505725,  0.18995722, -0.39541507,  0.14176926,
#        -0.07163918,  0.29748505,  0.34178996,  0.11692044, -0.172387  ,
#         0.48957464, -0.5240168 ,  0.1072486 ,  0.35868612,  0.08102184,
#         0.01456966,  0.19837163,  0.44778138, -0.00876657, -0.08622869,
#        -0.53869575,  0.09154525,  0.15541048,  0.09144475,  0.02012518,
#        -0.02224114,  0.5090085 ,  0.09279691, -0.31156844,  0.09059573,
#         0.11823533,  0.36243513,  0.03330509,  0.1465798 ,  0.05569758,
#        -0.40379456, -0.32618204, -0.18941352,  0.13330391,  0.0208647 ,
#         0.13245574, -0.23281574,  0.24429503, -0.21876574, -0.1966193 ,
#         0.35803318, -0.26514655, -0.68772656,  0.22980905, -0.2866401 ,
#        -0.29292423, -0.39605966, -0.3351311 , -0.03260257, -0.20122088,
#         0.28211156, -0.09383729, -0.28598633,  0.48763573, -0.18774778,
#         0.24669653, -0.07293358, -0.6532425 , -0.35576212, -0.07886984,
#         0.19644403,  0.08048049,  0.09799731, -0.18032554,  0.17367992,
#        -0.35160416, -0.07976519, -0.27886388,  0.11380348,  0.2959047 ,
#        -0.23467378,  0.13317579, -0.65900385,  0.32741064, -0.0799069 ,
#        -0.12234405, -0.04716406, -0.19034593,  0.05033912,  0.19835576,
#         0.07795059, -0.04610242,  0.40076736, -0.01947284,  0.27839237,
#        -0.27914035,  0.38755408, -0.4000678 , -0.3127803 , -0.06173648,
#        -0.32098272,  0.00335887,  0.7075298 , -0.57493424, -0.24998903,
#         0.38116667,  0.402053  , -0.27798143,  0.0108044 ,  0.08095957,
#        -0.26276553,  0.49584693, -0.13642617,  0.741981  , -0.06649013,
#        -0.3332629 ,  0.14159492,  0.18641815,  0.4212847 , -0.07026129,
#        -0.10150447,  0.17085007, -0.30141324, -0.0501546 ,  0.13099724,
#        -0.23575917,  0.06948724, -0.2930196 ,  0.3817789 , -0.13127846,
#        -0.00432168, -0.16897255,  0.27373904,  0.37090766,  0.31184936,
#        -0.36069238,  0.09237514,  0.5910716 ,  0.08410066,  0.38786888,
#        -0.375278  , -0.1710531 , -0.72187644,  0.6160853 , -0.05041498,
#        -0.11471657, -0.03145643, -0.08828597,  0.14942926,  0.09108663,
#         0.19215938, -0.05994676, -0.09095883,  0.45310518,  0.26072997,
#         0.30428728, -0.10657513,  0.33408046, -0.3830278 , -0.9907776 ,
#         0.02841476, -0.0311027 ,  0.1118333 , -0.18607572, -0.49513513,
#         0.10264961,  0.20543876,  0.59403485,  0.14039336,  0.01894412,
#        -0.3630358 , -0.07198428, -0.03292792, -0.01560279,  0.0204803 ,
#         0.11407115, -0.1337552 ,  0.04252672, -0.19491631, -0.28231436,
#         0.57382447, -0.03922805, -0.06637673,  0.31482607,  0.42726696,
#        -0.24986482,  0.2412833 , -0.13056597,  0.03021515, -0.05051159,
#        -0.11819532,  0.16205342,  0.20147978,  0.3605634 , -0.17381087,
#         0.0641073 ,  0.0788544 ,  0.28918105,  0.6062072 , -0.12962994,
#         0.25732484,  0.47212136,  0.2326965 ,  0.5015333 ,  0.24454924,
#         0.11284595, -0.06158319,  0.35680765, -0.44457918,  0.15517604,
#         0.03587395,  0.17342345, -0.24089478, -0.09558403,  0.5516244 ,
#        -0.15933189,  0.2151171 ,  0.01089653,  0.33193588,  0.05615536,
#        -0.40198338, -0.04945315,  0.09364093, -0.24845056,  0.03491344,
#         0.5071419 , -0.01778975,  0.7054196 , -0.34969145, -0.18376262,
#         0.05187009,  0.05392198,  0.29698554,  0.7901943 , -0.22913125,
#         0.27287692, -0.15455954, -0.32733333, -0.04939154, -0.20312373,
#         0.05558552,  0.33435336, -0.35955963, -0.20895183,  0.10020797,
#        -0.21786278, -0.35118967, -0.6585283 , -0.04895507, -0.42047206,
#        -0.23144425, -0.08549699, -0.4475517 ,  0.01414962,  0.46600813,
#        -0.46555927, -0.30151877, -0.34832847, -0.04425909, -0.0513553 ,
#         0.30117756, -0.09578827, -0.11111636, -0.37832272,  0.14868607,
#         0.07444364, -0.39044216, -0.14426479, -0.06574341, -0.17636144,
#         0.4977642 ,  0.02551395,  0.38934043,  0.19550748,  0.52911264,
#        -0.03886442,  0.11764485,  0.19252345, -0.49800456,  0.24215707,
#        -0.66855305,  0.01066698, -0.4247411 , -0.3357362 , -0.17389427,
#         0.30029023, -0.08177158,  0.23492669,  0.17298478,  0.522473  ,
#        -0.03076463, -0.12482572,  0.21638715,  0.06780324, -0.24212976,
#         0.32946256, -0.3302637 , -0.31153437, -0.26740208,  0.11623499,
#        -0.48573872, -0.10378377, -0.03522842, -0.20502001,  0.11374897,
#        -0.20345953,  0.09604286,  0.4960421 , -0.0036824 , -0.4009227 ,
#         0.10700615, -0.06762449, -0.00884654,  0.03231315, -0.27307168,
#         0.06155442, -0.04601865,  0.3355729 ,  0.22667152, -0.5397177 ,
#         0.57545817, -0.14213052, -0.3001347 ,  0.23852709,  0.14710218,
#         0.30977163,  0.09911311, -0.16457891,  0.119444  ,  0.38011676,
#         0.5020165 , -0.3415751 ,  0.2710892 ,  0.337961  ,  0.21026741,
#         0.0307443 , -0.2953269 , -0.07333645,  0.34398797,  0.79597783,
#         0.35654184,  0.10937953], dtype=float32)

# %% [markdown]
# ```bash
# (1, 512)
# (1, 512)
# ```
#
# ```{admonition} what is select_model?
# When fine-tuning CLIP, we are fine-tuning the CLIPVisionEncoder and CLIPTextEncoder in parallel.
# The artifact contains two models: `clip-vision` and `clip-text`.
# The parameter `select_model` tells finetuner which model to use for inference, in the above example,
# we use `clip-text` to encode a Document with text content.
# ```
#
# ```{admonition} Inference with ONNX
# In case you set `to_onnx=True` when calling `finetuner.fit` function,
# please use `model = finetuner.get_model(artifact, is_onnx=True)`
# ```

# %% [markdown]
# ## Advanced: WiSE-FT
#
# WiSE-FT, proposed by Mitchell et al. in [Robust fine-tuning of zero-shot models](https://arxiv.org/abs/2109.01903),
# has been proven to be an effective way for fine-tuning models with a strong zero-shot capability,
# such as CLIP.
# As was introduced in the paper:
#
# > Large pre-trained models such as CLIP or ALIGN offer consistent accuracy across a range of data distributions when performing zero-shot inference (i.e., without fine-tuning on a specific dataset). Although existing fine-tuning methods substantially improve accuracy on a given target distribution, they often reduce robustness to distribution shifts. We address this tension by introducing a simple and effective method for improving robustness while fine-tuning: ensembling the weights of the zero-shot and fine-tuned models (WiSE-FT).
#
# Finetuner allows you to apply WiSE-FT easily,
# all you need to do is use the `WiSEFTCallback`.
# Finetuner will trigger the callback when the fine-tuning job is finished and merge the weights between the pre-trained model and the fine-tuned model:
#
# ```diff
# from finetuner.callback import WiSEFTCallback
#
# run = finetuner.fit(
#     model='ViT-B-32#openai',
#     ...,
#     loss='CLIPLoss',
# -   callbacks=[],
# +   callbacks=[WiSEFTCallback(alpha=0.5)],
# )
# ```
#
# The value you set for `alpha` should be greater than or equal to 0 and less than or equal to 1:
#
# + if `alpha` is a float between 0 and 1, we merge the weights between the pre-trained model and the fine-tuned model.
# + if `alpha` is 0, the fine-tuned model is identical to the pre-trained model.
# + if `alpha` is 1, the pre-trained weights will not be utilized.
#
#
# That's it! Check out [clip-as-service](https://clip-as-service.jina.ai/user-guides/finetuner/?highlight=finetuner#fine-tune-models) to learn how to plug in a fine-tuned CLIP model to our CLIP-specific service.

# %% [markdown]
# ## Before and after
# We can directly compare the results of our fine-tuned model with a pre-trained clip model by displaying the matches each model has for the same query. While the differences between the results of the two models are quite subtle for some queries, the examples below clearly show that finetuning increases the quality of the search results:

# %%
finetuner.login()

token = finetuner.get_token()
run = finetuner.get_run(
    experiment_name='default',
    run_name='practical-sammet'
)

model = finetuner.get_model(
    run.artifact_id,
    token=token,
    select_model='clip-text'
)

texts = ['some text to encode']

embeddings = finetuner.encode(model=model, data=texts)

for text, embedding in zip(texts, embeddings):
    print(f'Text of the returned document: {text}')
    print(f'Shape of the embedding: {embedding.shape}')
# Out:
# VBox(children=(HTML(value="\n<div class='custom-container'>\n    <style>\n        .custom-container {\n       …
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Text of the returned document: some text to encode
# Shape of the embedding: (512,)

# %% [markdown]
# ```plaintext
# Results for query: "nightingale tee jacket" using a zero-shot model (top) and the fine-tuned model (bottom)
# ```
# ![clip-example-pt](https://user-images.githubusercontent.com/6599259/212634395-6f336d39-cda7-425d-80a2-10facae3b824.png)
#
# ![clip-example-ft](https://user-images.githubusercontent.com/6599259/212634112-a44c6c4c-2cc1-4dfb-8e29-0d02b2d6b95c.png)
